# %% [markdown]
# # 调用线上的大模型
#
# ## 1. 调用具体模型厂商的API
#
# ### 1.1 调用deepseek官网的deepseek模型
# 调用大模型涉及到三个特别重要的参数：base_url、 model_name 、 api_key
# ep1：将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek
from langchain_openai import ChatOpenAI
from langchain_openrouter import ChatOpenRouter

# 读取.env配置文件中的信息。 相关环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_key = os.getenv("DEEPSEEK_API_key")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化

llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_key,
    api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response = llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，一个由深度求索公司创造的免费AI助手，知识截止于2025年5月，能够处理长达1M上下文的复杂任务并支持文件上传与联网搜索功能。' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户要求用一句话介绍自己。这是一个非常直接且简单的请求。我需要用最精炼的语言概括自己的核心身份和功能。我是DeepSeek，一个AI助手。主要特点是免费、知识截止到2025年5月、支持长上下文和文件处理。把关键信息串联成一句通顺的话就可以了。'} response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 9, 'total_tokens': 122, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 69, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'c5a98cbf-e71c-4291-a188-b0c01141f920', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f73dd-c321-7993-8cb1-9477f3b2dea6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 113, 'total_tokens': 122, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 69}}

# %% [markdown]
# 举例2：是对举例一的优化

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 读取.env配置文件中的信息。 相关环境变量以.env文件中的优先
load_dotenv(override=True)

# DEEPSEEK_API_key = os.getenv("DEEPSEEK_API_key")
# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化

llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_key,
    # api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response = llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，由深度求索公司创造的AI助手，乐于免费为你提供帮助，支持长文本、联网搜索和文件处理等多种功能。' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户让我用一句话介绍自己。这是一个非常直接简单的请求。我需要用最简洁、最概括的方式说明自己的身份和核心功能。\n\n想到了，可以用“我是DeepSeek，由深度求索公司创造的AI助手”来明确身份。然后需要突出我的主要能力，也就是“文本模型”，并强调我乐于助人、免费、并且支持多种高级功能，比如联网搜索和文件处理。\n\n这样一句话就涵盖了我是谁、我能做什么、以及我的关键特点。应该能满足用户的要求了。'} response_metadata={'token_usage': {'completion_tokens': 140, 'prompt_tokens': 9, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 107, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'fb2f99d3-5c63-44eb-b61f-3c89720f579b', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f7402-a583-7bd1-8b32-9e57bf9118ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 140, 'total_tokens': 149, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 107}}

# %% [markdown]
# ## 2.兼容的写法
#
# 使用chatopenai
#
# 举例1：调用deepseek官网提供的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_key = os.getenv("DEEPSEEK_API_key")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")



#获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_key,
    base_url=DEEPSEEK_BASE_URL,
)

response = model.invoke("1 + 1 = ?")

print(response)
# Out:
# content='1 + 1 = 2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 10, 'total_tokens': 51, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 33, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'cb1aa4ca-292f-4f05-b901-ccf55fd7de58', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f73ff-f633-7c91-9f76-4a4b729093f0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 41, 'total_tokens': 51, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 33}}
